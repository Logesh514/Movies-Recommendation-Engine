# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
movies = pd.DataFrame({
    'title': [
        'Avatar',
        'Titanic',
        'Avengers',
        'Iron Man',
        'The Notebook',
        'Endgame'
    ],
    'genre': [
        'Action Adventure Sci-Fi',
        'Romance Drama',
        'Action Superhero',
        'Action Superhero',
        'Romance Drama',
        'Action Superhero'
    ]
})

movies
# Out:
#           title                    genre
# 0        Avatar  Action Adventure Sci-Fi
# 1       Titanic            Romance Drama
# 2      Avengers         Action Superhero
# 3      Iron Man         Action Superhero
# 4  The Notebook            Romance Drama
# 5       Endgame         Action Superhero

# %%
cv = CountVectorizer()

matrix = cv.fit_transform(movies['genre'])

similarity = cosine_similarity(matrix)

# %%
movie_name = "Avengers"

index = movies[movies['title'] == movie_name].index[0]

scores = list(enumerate(similarity[index]))

scores = sorted(scores, key=lambda x: x[1], reverse=True)

scores
# Out:
# [(2, np.float64(0.9999999999999998)),
#  (3, np.float64(0.9999999999999998)),
#  (5, np.float64(0.9999999999999998)),
#  (0, np.float64(0.35355339059327373)),
#  (1, np.float64(0.0)),
#  (4, np.float64(0.0))]

# %%
print("Recommended Movies:")

for movie in scores[1:4]:
    print(movies.iloc[movie[0]].title)
# Out:
# Recommended Movies:
# Iron Man
# Endgame
# Avatar

# %%
movie_name = "Titanic"

index = movies[movies['title'] == movie_name].index[0]

scores = list(enumerate(similarity[index]))

scores = sorted(scores, key=lambda x: x[1], reverse=True)

print("Recommended Movies:")

for movie in scores[1:3]:
    print(movies.iloc[movie[0]].title)
# Out:
# Recommended Movies:
# The Notebook
# Avatar
